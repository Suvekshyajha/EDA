# %%
import pandas as pd
import matplotlib.pyplot as py
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns:", numerical_cols)

# Categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Numerical columns: Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')
# Categorical columns: Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# counting total number of passengers

# %%
df['PassengerId'].nunique()
# Out:
# 418

# %% [markdown]
# counting num of males and females

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex', data=df, palette='pastel')
py.title('bar diagram of gender')
py.xlabel('gender')
py.ylabel('no_of_passengers')
py.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16668\4038513990.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=df, palette='pastel')

# %% [markdown]
# measures of central tendency on age

# %%
df['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
median_Age=df['Age'].median()
mode_Age=df['Age'].mode()[0]

print(f"median age is {median_Age}")
print(f"modal age is {mode_Age}")
# Out:
# median age is 27.0
# modal age is 21.0

# %% [markdown]
# ->average age of passenger is 30.27,
# ->median age is 27 which means half of passengers were younger
# than 27 yrs old and then other half older than 27
# ->modal age is 21 which means most repeated age is 21 yrs old.

# %%
bins = np.arange(0, 101, 10) 
sns.histplot(df['Age'],bins=bins,color='pink')
py.title('histogram on Age')
py.xlabel('age')
py.ylabel('passenger')
# Out:
# Text(0, 0.5, 'passenger')

# %% [markdown]
# calculating no of passengers in pclass

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=df, palette='pastel')
py.title('bar Diagram on passenger class')
py.xlabel('class')
py.ylabel('no of passengers')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16668\1108977899.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=df, palette='pastel')
# Text(0, 0.5, 'no of passengers')

# %% [markdown]
# calculate average fare

# %%
median_fare = df['Fare'].median()
print(f"Median fare is {median_fare}")
# Out:
# Average fare is 35.63
# Median fare is 14.4542

# %%
#descriptive stat on fare

# %%
df['Fare'].describe()
# Out:
# count    417.000000
# mean      35.627188
# std       55.907576
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.500000
# max      512.329200
# Name: Fare, dtype: float64

# %%
bins = np.arange(0, df['Fare'].max() + 10, 10)
sns.histplot(df['Fare'],bins=bins,color='pink')

py.title('histogram on fare')
py.xlabel('fare')
py.ylabel('no of passengers')
# Out:
# Text(0, 0.5, 'no of passengers')

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
df['Embarked'].describe(include=['object'])
# Out:
# count     418
# unique      3
# top         S
# freq      270
# Name: Embarked, dtype: object

# %%
sns.countplot(x='Embarked',data=df)
py.title('Embarked')
py.xlabel('emabarked port name')
py.ylabel('no of passengers')
# Out:
# Text(0, 0.5, 'no of passengers')

# %% [markdown]
# in conclusion there are 418 passengers(266 male,152 female),average age was 30.27.there were 3 classes:in 3rd class(218 people),2nd class(93 people),in 1st class(107 people).Average fare was 35 and maximum fare was 512.39.270 people departed from southhampton port,102 from Cherbourg and 46 from queenstown.
